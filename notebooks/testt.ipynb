# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import requests
import json
import geopandas as gpd
from shapely.geometry import Polygon, Point, MultiPolygon
from pyproj import Transformer

from query.query_tools import ArcGISQuery, Data_Collection

# %%
urls = {'AREAS_ACTIVIDADES_PARA_MAYORES': 'https://sigma.madrid.es/hosted/rest/services/GEOPORTAL/AREAS_ACTIVIDADES_PARA_MAYORES/MapServer/0'}

# %%
with open('urls.json', 'w') as f:
    json.dump(urls, f)

# %%
dd.data
# Out:
# {'AREAS_ACTIVIDADES_PARA_MAYORES':      ESRI_OID DESC_CLASIFICACION     TIPO     ESTADO FECHA_INSTALACION  \
#  0           1    Área de mayores  MAYORES  OPERATIVO        2004-01-01
#  1           2    Área de mayores  MAYORES  OPERATIVO        2004-01-01
#  2           3    Área de mayores  MAYORES  OPERATIVO        2004-01-01
#  3           4    Área de mayores  MAYORES  OPERATIVO        2007-04-24
#  4           5    Área de mayores  MAYORES  OPERATIVO        2011-04-15
#  ..        ...                ...      ...        ...               ...
#  300       301    Área de mayores  MAYORES  OPERATIVO        2022-02-24
#  301       302    Área de mayores  MAYORES  OPERATIVO        2022-02-24
#  302       303    Área de mayores  MAYORES  OPERATIVO        2022-03-28
#  303       304    Área de mayores  MAYORES  OPERATIVO        2022-04-04
#  304       305    Área de mayores  MAYORES  OPERATIVO               NaT
#
#       TOTAL_ELEM  TIPO_VIA                     NOM_VIA NUM_VIA       NDP  \
#  0             9      <NA>                        <NA>    <NA>  11006381
#  1            16      <NA>                        <NA>    <NA>  11005467
#  2             2  GLORIETA            PUERTA DE TOLEDO       1  20105763
#  3            10      <NA>                        <NA>    <NA>  31047998
#  4             2      <NA>                        <NA>    <NA>  11005153
#  ..          ...       ...                         ...     ...       ...
#  300          11     CALLE  MADRES DE LA PLAZA DE MAYO       5  20169092
#  301          11     CALLE             GABRIEL MONTERO       5  20076103
#  302           7     CALLE                    BASILICA      17  11029304
#  303           8     CALLE        VIZCONDE DE ARLESSON      37  11093791
#  304           0      <NA>                        <NA>    <NA>      <NA>
#
#                                           DIRECCION_AUX COD_POSTAL  \
#  0    Pza · PLAZA COMENDADORAS , ASCENDIENTE 1: 015 · U       <NA>
#  1    Pza · PLAZA PLAZA DOS DE MAYO , ASCENDIENTE 1: 01       <NA>
#  2     Pza · PLAZA PLAZA PUERTA DE TOLEDO , ASCENDIENTE      28005
#  3    Parque · PARQUE PARQUE /CASINO DE LA REINA/(C/EMB       <NA>
#  4     Pza · PLAZA PLAZA SANTA BARBARA , ASCENDIENTE 1:       <NA>
#  ..                                                 ...        ...
#  300                                  C/VICENTE ESPINEL      28017
#  301  C · CALLE GANDHI , ASCENDIENTE 1: 152 · PUEBLO NU      28017
#  302                                             ORENSE      28020
#  303                                  CV C/DE LA IMAGEN      28018
#  304                                               <NA>      28005
#
#               BARRIO            DISTRITO  OBJECTID  \
#  0       UNIVERSIDAD              CENTRO         1
#  1       UNIVERSIDAD              CENTRO         2
#  2       EMBAJADORES              CENTRO         3
#  3       EMBAJADORES              CENTRO         4
#  4          JUSTICIA              CENTRO         5
#  ..              ...                 ...       ...
#  300    PUEBLO NUEVO       CIUDAD LINEAL       301
#  301    PUEBLO NUEVO       CIUDAD LINEAL       302
#  302  CUATRO CAMINOS              TETUAN       303
#  303       SAN DIEGO  PUENTE DE VALLECAS       304
#  304   CASA DE CAMPO   MONCLOA - ARAVACA       305
#
#                                SHAPE
#  0     POINT (439837.18 4475417.538)
#  1    POINT (440301.829 4475401.703)
#  2     POINT (439694.34 4473203.414)
#  3     POINT (440249.13 4473137.655)
#  4    POINT (440953.794 4475414.478)
#  ..                              ...
#  300  POINT (445598.543 4476007.538)
#  301   POINT (446566.606 4475140.79)
#  302   POINT (441011.31 4477874.668)
#  303  POINT (443356.563 4470485.518)
#  304   POINT (438636.028 4474770.23)
#
#  [305 rows x 16 columns]}
